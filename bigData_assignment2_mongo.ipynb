# %%
#imports

import numpy as np
import pandas as pd
import pymongo
from pymongo import MongoClient
import urllib.parse
from bson.json_util import dumps
from datetime import datetime

# %%
# Connect to the Database

username = urllib.parse.quote_plus('amrsamir01') # replace <<USERNAME>> with your own MongoDB username
password = urllib.parse.quote_plus("Amrsamir2001") # replace <<PASSWORD>> with your own MongoDB password

url = "mongodb+srv://amrsamir01:Amrsamir2001@cluster0.yh2yd.mongodb.net/?retryWrites=true&w=majority".format(username, password) # replace <<CLUSTERNAME>> with your cluster's name and <<DATABASENAME>> with your database's name
cluster = MongoClient(url, connect=False)

db = cluster["Taxi"] # replace <<DATABASENAME>> with your database's name
collection = db["taxi"]

db1 = cluster["Trip"]
collection1 = db1["trip"]

# %%
#read the file

trip_df = pd.read_csv('D:/computer science GIU/semester 6/BigData/GIU_2718_56_7524_2022-05-17T10_13_53/datasets/taxi_trip_data.csv', encoding= 'unicode_escape') # edit path accordingly to read from where the listings.csv file is
i,j = trip_df.shape
trip_df
# Out:
#          vendor_id      pickup_datetime     dropoff_datetime  passenger_count  \
# 0                1  2018-05-11 17:40:16  2018-05-11 17:55:35                1
# 1                2  2018-03-22 23:01:41  2018-03-22 23:25:36                1
# 2                2  2018-07-24 09:58:45  2018-07-24 10:22:37                1
# 3                2  2018-12-21 18:28:55  2018-12-21 18:35:45                1
# 4                1  2018-08-15 13:58:39  2018-08-15 14:05:25                1
# ...            ...                  ...                  ...              ...
# 9999995          2  2018-08-23 14:25:50  2018-08-23 14:44:10                1
# 9999996          2  2018-06-19 20:20:11  2018-06-19 20:24:03                1
# 9999997          1  2018-06-30 19:42:55  2018-06-30 19:56:53                4
# 9999998          1  2018-12-31 14:26:33  2018-12-31 14:33:18                1
# 9999999          1  2018-05-30 23:24:56  2018-05-30 23:28:27                1
#
# ...

# %%
#read the file

zone_df = pd.read_csv('D:/computer science GIU/semester 6/BigData/GIU_2718_56_7524_2022-05-17T10_13_53/datasets/taxi_zone_geo.csv', encoding= 'unicode_escape') # edit path accordingly to read from where the listings.csv file is
i,j = zone_df.shape

# %%
#for query number 2 there are not ant missing values in the data

# %%
#Query number 1 and 3
#Insert the data into the Database and remove the three columns

taxi_trips = []
for x in range(0,2000):
    taxi_trips = taxi_trips + [{'vendor_id': int(trip_df.loc[x].vendor_id),
                                'pickup_datetime': datetime.strptime(trip_df.loc[x].pickup_datetime, '%Y-%m-%d %H:%M:%S'),
                                'dropoff_datetime': datetime.strptime(trip_df.loc[x].dropoff_datetime, '%Y-%m-%d %H:%M:%S'),
                                'passenger_count': int(trip_df.loc[x].passenger_count), 
                                'trip_distance': float(trip_df.loc[x].trip_distance), 
                                #'rate code': '%s' % (trip_df.loc[x].rate_code), 
                                #'store and fwd flag': '%s' % (trip_df.loc[x].store_and_fwd_flag), 
                                'payment_type': int(trip_df.loc[x].payment_type), 
                                'fare_amount': float(trip_df.loc[x].fare_amount), 
                                'extra': float(trip_df.loc[x].extra), 
                                'mta_tax': float(trip_df.loc[x].mta_tax), 
                                'tip_amount': float(trip_df.loc[x].tip_amount), 
                                'tolls_amount': float(trip_df.loc[x].tolls_amount), 
                                'imp_surcharge': float(trip_df.loc[x].imp_surcharge), 
                                #'total amount': '%d' % (trip_df.loc[x].total_amount), 
                                'pickup_location_id': int(trip_df.loc[x].pickup_location_id), 
                                'dropoff_location_id': int(trip_df.loc[x].dropoff_location_id),
                               }]
collection.insert_many(taxi_trips)

# %%
#Query number 4
#Calculate the duration

duration=collection.aggregate([
    {
        "$project":{
            "item":1, "duration":{
                "$divide": [{
                    "$subtract":["$dropoff_datetime", "$pickup_datetime"]
                }, 1000*60 ] 
            }
        }
    },
])
dur=[]
for i in duration:
    print("duration is",i['duration'])
    dur= dur+[{'duration': i['duration']}]
d = pd.DataFrame(dur)
# Out:
# duration is 15.316666666666666
# duration is 23.916666666666668
# duration is 23.866666666666667
# duration is 6.833333333333333
# duration is 6.766666666666667
# duration is 52.4
# duration is 23.466666666666665
# duration is 5.433333333333334
# duration is 10.333333333333334
# duration is 24.1
# duration is 19.416666666666668
# duration is 19.216666666666665
# duration is 13.0
# duration is 10.616666666666667
# duration is 3.9833333333333334
# duration is 10.45
# duration is 27.266666666666666
# duration is 8.366666666666667
# duration is 9.15
# duration is 15.383333333333333
# duration is 21.983333333333334
# duration is 5.7
# duration is 9.65
# duration is 7.766666666666667
# duration is 6.483333333333333
# duration is 7.05
# duration is 47.05
# duration is 18.6
# duration is 4.6
# duration is 2.466666666666667
# duration is 13.416666666666666
# duration is 12.966666666666667
# duration is 9.366666666666667
# duration is 14.1
# duration is 8.85
# duration is 3.3833333333333333
# ...

# %%
#Query number 5
#Calculate the trip cost

trip_cost = collection.aggregate(
    [
        { 
            "$project" : {
                "total_trip_cost" : { 
                    "$add": ["$extra", "$mta_tax", "$tip_amount", "$tolls_amount", "$imp_surcharge"]
                }
            }
        }
    ]
)
#collection.insert_many(trip_cost)
tr_cost = []
for i in trip_cost:
    print("total trip cost is: ",i['total_trip_cost'])
    tr_cost= tr_cost+[{'trip_cost': i['total_trip_cost']}]
trip_c = pd.DataFrame(tr_cost)
# Out:
# total trip cost is:  1.8
# total trip cost is:  7.26
# total trip cost is:  2.3
# total trip cost is:  1.8
# total trip cost is:  0.8
# total trip cost is:  7.55
# total trip cost is:  6.75
# total trip cost is:  2.56
# total trip cost is:  1.3
# total trip cost is:  6.1499999999999995
# total trip cost is:  6.0
# total trip cost is:  3.8499999999999996
# total trip cost is:  4.06
# total trip cost is:  1.8
# total trip cost is:  0.8
# total trip cost is:  0.8
# total trip cost is:  28.25
# total trip cost is:  2.23
# total trip cost is:  2.8
# total trip cost is:  0.8
# total trip cost is:  5.55
# total trip cost is:  1.8
# total trip cost is:  2.85
# total trip cost is:  0.8
# total trip cost is:  2.16
# total trip cost is:  1.3
# total trip cost is:  13.4
# total trip cost is:  1.3
# total trip cost is:  2.88
# total trip cost is:  0.8
# total trip cost is:  1.3
# total trip cost is:  1.8
# total trip cost is:  3.25
# total trip cost is:  1.8
# ...

# %%
#read the data again with parse_dates

df = pd.read_csv('D:/computer science GIU/semester 6/BigData/GIU_2718_56_7524_2022-05-17T10_13_53/datasets/taxi_trip_data.csv', encoding= 'unicode_escape', parse_dates=["pickup_datetime", "dropoff_datetime"]) # edit path accordingly to read from where the listings.csv file is
i,j = df.shape

# %%
#Query number 6
#the most common payment type

morning = []
afternoon = []
evening = []
for i in range (0, 2000):
    if(df.loc[i].pickup_datetime.hour >= 5 and df.loc[i].pickup_datetime.hour < 12):
        morning.append(df.iloc[i]['payment_type'])
    if(df.loc[i].pickup_datetime.hour >= 12 and df.loc[i].pickup_datetime.hour < 17):
        afternoon.append(df.iloc[i]['payment_type'])
    if (df.loc[i].pickup_datetime.hour>= 17 and df.loc[i].pickup_datetime.hour < 21):
            evening.append(df.iloc[i]['payment_type'])

# %%
# 1=Credit_card 2=Cash 3=No_charge 4=Dispute 5=Unknown 6=Voidedtrip

a = np.array(morning)
unique, counts = np.unique(a, return_counts=True)
dict(zip(unique, counts))
# Out:
# {1: 333, 2: 173, 3: 1, 4: 4}

# %%
# 1=Credit_card 2=Cash 3=No_charge 4=Dispute 5=Unknown 6=Voidedtrip

a = np.array(afternoon)
unique, counts = np.unique(a, return_counts=True)
dict(zip(unique, counts))
# Out:
# {1: 335, 2: 180, 3: 1, 4: 3}

# %%
# 1=Credit_card 2=Cash 3=No_charge 4=Dispute 5=Unknown 6=Voidedtrip

a = np.array(evening)
unique, counts = np.unique(a, return_counts=True)
dict(zip(unique, counts))
# Out:
# {1: 304, 2: 155, 3: 3}

# %%
#Query number 7
#Calculate the tip average
tip = collection.aggregate(
    [
        {
            '$project': {
                "tip_avg": {
                    '$avg':["$tip_amount"]
                }
            }
        },
    ]
)
for l in tip:
    print("tip average is: ",l['tip_avg'])
# Out:
# tip average is:  0.0
# tip average is:  5.96
# tip average is:  1.5
# tip average is:  0.0
# tip average is:  0.0
# tip average is:  6.75
# tip average is:  5.45
# tip average is:  1.26
# tip average is:  0.0
# tip average is:  5.35
# tip average is:  4.7
# tip average is:  3.05
# tip average is:  2.26
# tip average is:  0.0
# tip average is:  0.0
# tip average is:  0.0
# tip average is:  17.45
# tip average is:  0.93
# tip average is:  1.5
# tip average is:  0.0
# tip average is:  3.75
# tip average is:  0.0
# tip average is:  1.55
# tip average is:  0.0
# tip average is:  1.36
# tip average is:  0.0
# tip average is:  11.6
# tip average is:  0.0
# tip average is:  1.58
# tip average is:  0.0
# tip average is:  0.0
# tip average is:  0.0
# tip average is:  2.45
# tip average is:  1.0
# tip average is:  2.05
# tip average is:  1.26
# tip average is:  9.96
# tip average is:  1.35
# tip average is:  3.25
# tip average is:  1.75
# tip average is:  7.82
# tip average is:  0.0
# ...

# %%
"""tip = collection.aggregate(
    [
        {
            '$project': {
                "tip_avg": {"$divide":[{
                 '$avg':["$tip_amount"]},"$passenger_count"]   
                }
            }
        },
    ]
)
for l in tip:
    print("tip average is: ",l['tip_avg'])
"""
# Out:
# 'tip = collection.aggregate(\n    [\n        {\n            \'$project\': {\n                "tip_avg": {"$divide":[{\n                 \'$avg\':["$tip_amount"]},"$passenger_count"]   \n                }\n            }\n        },\n    ]\n)\nfor l in tip:\n    print("tip average is: ",l[\'tip_avg\'])\n'

# %%
#Query number 8
#Calculate the best 5 locations
top_5 = collection.aggregate(
    [
        {
            "$group": {
                "_id": {"pickup_location_id" : "$pickup_location_id"},
                 "count": {"$sum": 1} }
        },
        {
            "$sort" : { "count" : -1 } 
        },
        {
            "$limit" : 5
        },
    ]
)
print("the best 5 locations are:")
for l in top_5:
    print(l['_id'],"count:",l['count'])
# Out:
# the best 5 locations are:
# {'pickup_location_id': 237} count: 84
# {'pickup_location_id': 161} count: 79
# {'pickup_location_id': 230} count: 74
# {'pickup_location_id': 186} count: 70
# {'pickup_location_id': 170} count: 65

# %%
#Insert the data with the new fields: duration and trip cost
taxi_trips = []
for x in range(0,2000):
    taxi_trips = taxi_trips + [{'vendor_id': int(trip_df.loc[x].vendor_id),
                                'pickup_datetime': datetime.strptime(trip_df.loc[x].pickup_datetime, '%Y-%m-%d %H:%M:%S'),
                                'dropoff_datetime': datetime.strptime(trip_df.loc[x].dropoff_datetime, '%Y-%m-%d %H:%M:%S'),
                                'passenger_count': int(trip_df.loc[x].passenger_count), 
                                'trip_distance': float(trip_df.loc[x].trip_distance), 
                                'payment_type': int(trip_df.loc[x].payment_type), 
                                'fare_amount': float(trip_df.loc[x].fare_amount), 
                                'extra': float(trip_df.loc[x].extra), 
                                'mta_tax': float(trip_df.loc[x].mta_tax), 
                                'tip_amount': float(trip_df.loc[x].tip_amount), 
                                'tolls_amount': float(trip_df.loc[x].tolls_amount), 
                                'imp_surcharge': float(trip_df.loc[x].imp_surcharge), 
                                'pickup_location_id': int(trip_df.loc[x].pickup_location_id), 
                                'dropoff_location_id': int(trip_df.loc[x].dropoff_location_id), 
                                'trip_cost': float(trip_c.loc[x].trip_cost),
                                'duration': float(d.loc[x].duration)}]
collection1.insert_many(taxi_trips)
